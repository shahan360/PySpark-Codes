# %% [markdown]
# <a href="https://colab.research.google.com/github/shahan360/PySpark-Codes/blob/main/Convert_PySpark_RDD_to_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Create PySpark RDD**

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('PySparkRDDtoDataFrame').getOrCreate()
dept = [("Finance",10),("Marketing",20),("Sales",30),("IT",40)]
rdd = spark.sparkContext.parallelize(dept)

# %% [markdown]
# # **2. Convert PySpark RDD to DataFrame**

# %% [markdown]
# 2.1 Using rdd.toDF() function

# %%
df = rdd.toDF()
df.printSchema()
df.show(truncate=False)
# Out:
# root
#  |-- _1: string (nullable = true)
#  |-- _2: long (nullable = true)
#
# +---------+---+
# |_1       |_2 |
# +---------+---+
# |Finance  |10 |
# |Marketing|20 |
# |Sales    |30 |
# |IT       |40 |
# +---------+---+

# %%
deptColumns = ["dept_name","dept_id"]
df2 = rdd.toDF(deptColumns)
df2.printSchema()
df2.show(truncate=False)
# Out:
# root
#  |-- dept_name: string (nullable = true)
#  |-- dept_id: long (nullable = true)
#
# +---------+-------+
# |dept_name|dept_id|
# +---------+-------+
# |Finance  |10     |
# |Marketing|20     |
# |Sales    |30     |
# |IT       |40     |
# +---------+-------+

# %% [markdown]
# 2.2 Using PySpark createDataFrame() function

# %%
deptDF = spark.createDataFrame(rdd, schema = deptColumns)
deptDF.printSchema()
deptDF.show(truncate=False)
# Out:
# root
#  |-- dept_name: string (nullable = true)
#  |-- dept_id: long (nullable = true)
#
# +---------+-------+
# |dept_name|dept_id|
# +---------+-------+
# |Finance  |10     |
# |Marketing|20     |
# |Sales    |30     |
# |IT       |40     |
# +---------+-------+

# %% [markdown]
# ### 2.3 Using createDataFrame() with StructType schema
#
# When you infer the schema, by default the datatype of the columns is derived from the data and set’s nullable to true for all columns. We can change this behavior by supplying schema using StructType – where we can specify a column name, data type and nullable for each field/column.

# %%
from pyspark.sql.types import StructType, StructField, StringType
deptSchema = StructType([
    StructField('dept_name', StringType(), True),
    StructField('dept_id', StringType(), True)
])

deptDF1 = spark.createDataFrame(rdd, schema = deptSchema)
deptDF1.printSchema()
deptDF1.show(truncate=False)
# Out:
# root
#  |-- dept_name: string (nullable = true)
#  |-- dept_id: string (nullable = true)
#
# +---------+-------+
# |dept_name|dept_id|
# +---------+-------+
# |Finance  |10     |
# |Marketing|20     |
# |Sales    |30     |
# |IT       |40     |
# +---------+-------+
